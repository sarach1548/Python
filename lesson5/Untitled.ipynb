# %%
pip install pandas
# Out:
# ...
#
#   Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.0-cp310-cp310-win_amd64.whl (11.6 MB)
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_19996\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = {'name': ['אליז', 'בת שבע', 'גליה'],
        'mark': [85, 92, 100],
        'grade': [' 2','3', '2']}

# %%
sample = pd.DataFrame(data)
sample
# Out:
#      name  mark grade
# 0    אליז    85     2
# 1  בת שבע    92     3
# 2    גליה   100     2

# %%
newstd={'name':'רינה','mark':95,'grade':1}

# %%
sample.loc[len(sample)]=newstd

# %%
sample
# Out:
#      name  mark grade
# 0    אליז    85     2
# 1  בת שבע    92     3
# 2    גליה   100     2
# 3    רינה    95     1

# %%
sample['name']
# Out:
# 0      אליז
# 1    בת שבע
# 2      גליה
# 3      רינה
# Name: name, dtype: object

# %%
sample['grade']
# sample[sample['grade']==3]
# Out:
# 0     2
# 1     3
# 2     2
# 3     1
# Name: grade, dtype: object

# %%
sample[sample.mark==sample.mark.max()]
# Out:
#    name  mark grade
# 2  גליה   100     2

# %% [markdown]
# תרגיל 2:

# %%
 df=pd.read_csv("Z:\B\חזקיהו שרה\פייתון מתקדם\cities.csv")

# %%
df
# Out:
#      LatD   LatM   LatS    NS   LonD   LonM   LonS    EW                City  \
# 0      41      5     59   "N"     80   39.0      0   "W"        "Youngstown"
# 1      42     52     48   "N"     97   23.0     23   "W"           "Yankton"
# 2      46     35     59   "N"    120   30.0     36   "W"            "Yakima"
# 3      42     16     12   "N"     71    NaN      0   "W"         "Worcester"
# 4      43     37     48   "N"     89   46.0     11   "W"   "Wisconsin Dells"
# ..    ...    ...    ...   ...    ...    ...    ...   ...                 ...
# 123    39     31     12   "N"    119   48.0     35   "W"                 NaN
# 124    50     25     11   "N"    104   39.0      0   "W"            "Regina"
# 125    40     10     48   "N"    122   14.0     23   "W"         "Red Bluff"
# 126    40     19     48   "N"     75   55.0     48   "W"           "Reading"
# 127    41      9     35   NaN     81   14.0     23   "W"           "Ravenna"
#
#      State
# 0       OH
# 1       SD
# ...

# %%
df.isnull().sum()
# Out:
# LatD      0
#  LatM     0
#  LatS     0
#  NS       1
#  LonD     0
#  LonM     1
#  LonS     0
#  EW       0
#  City     1
#  State    0
# dtype: int64

# %%
df['NS']

# %%
df.LatD.mean()
# Out:
# 38.8203125

# %%
df.LatD.max()
# Out:
# 50

# %%
df.LatD.min()
# Out:
# 26

# %%
df['yachas']=df.LatD/df.LatD

# %%
df
# Out:
#      LatD   LatM   LatS    NS   LonD   LonM   LonS    EW                City  \
# 0      41      5     59   "N"     80   39.0      0   "W"        "Youngstown"
# 1      42     52     48   "N"     97   23.0     23   "W"           "Yankton"
# 2      46     35     59   "N"    120   30.0     36   "W"            "Yakima"
# 3      42     16     12   "N"     71    NaN      0   "W"         "Worcester"
# 4      43     37     48   "N"     89   46.0     11   "W"   "Wisconsin Dells"
# ..    ...    ...    ...   ...    ...    ...    ...   ...                 ...
# 123    39     31     12   "N"    119   48.0     35   "W"                 NaN
# 124    50     25     11   "N"    104   39.0      0   "W"            "Regina"
# 125    40     10     48   "N"    122   14.0     23   "W"         "Red Bluff"
# 126    40     19     48   "N"     75   55.0     48   "W"           "Reading"
# 127    41      9     35   NaN     81   14.0     23   "W"           "Ravenna"
#
#      State  yachas
# 0       OH     1.0
# ...

# %%
df.rename(columns={"LatD":"Population"})
# Out:
#      Population   LatM   LatS    NS   LonD   LonM   LonS    EW  \
# 0            41      5     59   "N"     80   39.0      0   "W"
# 1            42     52     48   "N"     97   23.0     23   "W"
# 2            46     35     59   "N"    120   30.0     36   "W"
# 3            42     16     12   "N"     71    NaN      0   "W"
# 4            43     37     48   "N"     89   46.0     11   "W"
# ..          ...    ...    ...   ...    ...    ...    ...   ...
# 123          39     31     12   "N"    119   48.0     35   "W"
# 124          50     25     11   "N"    104   39.0      0   "W"
# 125          40     10     48   "N"    122   14.0     23   "W"
# 126          40     19     48   "N"     75   55.0     48   "W"
# 127          41      9     35   NaN     81   14.0     23   "W"
#
#                    City  State  yachas
# 0          "Youngstown"     OH     1.0
# 1             "Yankton"     SD     1.0
# 2              "Yakima"     WA     1.0
# 3           "Worcester"     MA     1.0
# ...

# %%
df.loc[3,['LatD']]
# Out:
# LatD    42
# Name: 3, dtype: object

# %%
df.sort_values('LatD')
# Out:
#      LatD   LatM   LatS    NS   LonD   LonM   LonS    EW                City  \
# 16     26     43     11   "N"     80    3.0      0   "W"   "West Palm Beach"
# 84     27     20     24   "N"     82   31.0     47   "W"          "Sarasota"
# 52     27     57      0   "N"     82   26.0     59   "W"             "Tampa"
# 31     28     48     35   "N"     97    0.0     36   "W"          "Victoria"
# 94     29     25     12   "N"     98   30.0      0   "W"       "San Antonio"
# ..    ...    ...    ...   ...    ...    ...    ...   ...                 ...
# 68     47     40     11   "N"    117   24.0     36   "W"           "Spokane"
# 10     48      9      0   "N"    103   37.0     12   "W"         "Williston"
# 33     49     16     12   "N"    123    7.0     12   "W"         "Vancouver"
# 6      49     52     48   "N"     97    9.0      0   "W"          "Winnipeg"
# 124    50     25     11   "N"    104   39.0      0   "W"            "Regina"
#
#      State  yachas
# 16      FL     1.0
# ...
