# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 809.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/15.8 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.2/15.8 MB 1.3 MB/s eta 0:00:13
#     --------------------------------------- 0.2/15.8 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.3/15.8 MB 1.5 MB/s eta 0:00:11
#    - -------------------------------------- 0.4/15.8 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/15.8 MB 1.7 MB/s eta 0:00:10
#    - -------------------------------------- 0.5/15.8 MB 1.6 MB/s eta 0:00:10
# ...

# %%
import numpy as np

# %%
arr=np.random.randint(1,50,size=(10))

# %%
arr
# Out:
# array([23, 23, 28,  3,  3,  2, 48, 42, 33, 49])

# %%
np.ndim(arr)
# Out:
# 1

# %%
arr.shape
# Out:
# (10,)

# %%
arr.size
# Out:
# 10

# %%
arr1=np.random.randint(10,100,size=(2,5))

# %%
arr1
# Out:
# array([[48, 30, 55, 29, 20],
#        [58, 68, 93, 75, 51]])

# %%
np.ndim(arr1)
# Out:
# 2

# %%
arr1.shape
# Out:
# (2, 5)

# %%
arr1.size
# Out:
# 10

# %%
arr.dtype
# Out:
# dtype('int32')
